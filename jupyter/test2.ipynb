# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as ms
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import metrics
import warnings
warnings.simplefilter(action = 'ignore')
data = pd.read_csv("D:\jupyter\diabetes.csv")
#读取数据值
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
data.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df = pd.DataFrame(data)
#将数据转化为DateDrame
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df = pd.DataFrame(data)
#将数据转化为DateDrame
df.describe(include='all')
#描述统计
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.isnull().sum()
#检查是否有数据值缺失
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print(data.Outcome.value_counts())
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
p = data.Outcome.value_counts().plot(kind = "bar", color = ['green' ,'red'], alpha = 0.6)

# %%
p = sns.pairplot(data ,kind = 'reg' ,diag_kind = 'hist')

# %%
p = sns.pairplot(data ,hue = 'Outcome')

# %%
outlier = ['Glucose','BloodPressure','SkinThickness','Insulin','BMI']
data[outlier] = data[outlier].replace(0,np.nan)
#对异常值赋予空值

# %%
p = ms.bar(data)
#查看数据的空值情况

# %%
th_count = data.shape[0]*0.8
#设定阀值，某一列数据缺失量超过20％就会被删除
data = data.dropna(thresh = th_count ,axis = 1)
p = ms.bar(data)

# %%
imp = SimpleImputer(strategy='mean')
col = ['Glucose', 'BloodPressure', 'BMI']
#对数值型变量的缺失值采用均值插补的方式填充
data[col] = imp.fit_transform(data[col])
p = ms.bar(data)

# %%
plt.figure(figsize = (12 ,10))
p = sns.heatmap(data.corr() ,annot = True)

# %%
x = pd.DataFrame(data,columns = ['Glucose','BloodPressure','BMI','DiabetesPedigreeFunction','Age','Pregnancies']).values
y = df.Outcome.values.reshape(-1,1)
x
# Out:
# array([[148.   ,  72.   ,  33.6  ,   0.627,  50.   ,   6.   ],
#        [ 85.   ,  66.   ,  26.6  ,   0.351,  31.   ,   1.   ],
#        [183.   ,  64.   ,  23.3  ,   0.672,  32.   ,   8.   ],
#        ...,
#        [121.   ,  72.   ,  26.2  ,   0.245,  30.   ,   5.   ],
#        [126.   ,  60.   ,  30.1  ,   0.349,  47.   ,   1.   ],
#        [ 93.   ,  70.   ,  30.4  ,   0.315,  23.   ,   1.   ]])

# %%
x_train ,x_test ,y_train ,y_test = train_test_split(x ,y , random_state = 0,test_size = 0.3 ,stratify = y)

# %%
clf = KNeighborsClassifier()
clf.fit(x_train ,y_train.ravel())
y_pred = clf.predict(x_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
#使用默认参数进行建模测试
# Out:
# Accuracy: 74.03%

# %%
k = 3
clf = KNeighborsClassifier(k)
clf.fit(x_train ,y_train.ravel())
y_pred = clf.predict(x_test)
#选择3个样本训练模型
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 74.46%

# %%
k = 9
clf = KNeighborsClassifier(k)
clf.fit(x_train ,y_train.ravel())
y_pred = clf.predict(x_test)
#选择9个样本训练模型
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 73.59%

# %%
k = 20
Acc = np.zeros((k))
for i in range(1 ,k+1):
    clf = KNeighborsClassifier(n_neighbors = i)
    clf.fit(x_train ,y_train.ravel())
    y_pred = clf.predict(x_test)
    Acc[i-1] = metrics.accuracy_score(y_test ,y_pred)
Acc
#计算各个K值的准确度并放进数组内
# Out:
# array([0.67532468, 0.72727273, 0.74458874, 0.74025974, 0.74025974,
#        0.73160173, 0.72727273, 0.73160173, 0.73593074, 0.72727273,
#        0.74458874, 0.74458874, 0.75324675, 0.73593074, 0.74025974,
#        0.74891775, 0.74458874, 0.74891775, 0.74891775, 0.74891775])

# %%
# 定义KNN分类器
knn = KNeighborsClassifier()
# 定义参数空间和搜索范围
array = np.arange(1,21)
param_grid = {'n_neighbors': array, 'weights': ['uniform', 'distance']}
# 定义评估指标和交叉验证折数
scoring = 'accuracy'
cv =9
# 创建GridSearchCV实例
grid = GridSearchCV(knn, param_grid, scoring=scoring, cv=cv)
# 训练模型并选择最佳参数组合
grid.fit(x_train ,y_train.ravel())
# 输出最佳参数组合和性能指标
print('Best parameters:', grid.best_params_)
print('Best score:', grid.best_score_)
# 使用最佳参数组合评估模型
best_knn = KNeighborsClassifier(n_neighbors=grid.best_params_['n_neighbors'], weights=grid.best_params_['weights'])
best_knn.fit(x_train ,y_train.ravel())
y_pred = best_knn.predict(x_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print(classification_report(y_pred, y_test))
#针对类别不均衡的情况，通过计算其精准度，召回率等来评判模型
#precision:精度=正确预测的个数(TP)/被预测正确的个数(TP+FP),即模型预测结果中多少是预测正确的
#recall:召回率=正确预测的个数(TP)/预测个数(TP+FN),即测试集总量中,有多少样本是预测正确的
#f1-score:F1=2*精度*召回率/(精度+召回率)
confusion = confusion_matrix(y_pred, y_test)
df_cm = pd.DataFrame(confusion)
sns.heatmap(df_cm, annot=True)
#混淆矩阵更能直观看出预测结果
###结果为：测试集中非糖尿病被预测为非糖尿病的有130例，糖尿病被预测为糖尿病的有46例，非糖尿病被预测为糖尿病的有35例，糖尿病被预测为非糖尿病的有22例。
# Out:
# Best parameters: {'n_neighbors': 13, 'weights': 'distance'}
# Best score: 0.7558380414312618
# Accuracy: 75.32%
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       163
#            1       0.57      0.68      0.62        68
#
#     accuracy                           0.75       231
#    macro avg       0.71      0.73      0.72       231
# weighted avg       0.77      0.75      0.76       231
# <Axes: >

# %%
gnb = GaussianNB()
gnb = GaussianNB()
gnb.fit(x_train,y_train.ravel())
y_pred = gnb.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 77.06%

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83       163
#            1       0.59      0.71      0.64        68
#
#     accuracy                           0.77       231
#    macro avg       0.73      0.75      0.74       231
# weighted avg       0.79      0.77      0.78       231

# %%
confusion = confusion_matrix(y_pred, y_test)
df_cm = pd.DataFrame(confusion)
sns.heatmap(df_cm, annot=True)
# Out:
# <Axes: >

# %%
rf = rf = RandomForestClassifier(random_state = 0)
rf.fit(x_train,y_train.ravel())
y_pred=rf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 76.62%

# %%
rf = rf = RandomForestClassifier(random_state = 0, criterion = 'entropy')
rf.fit(x_train,y_train.ravel())
y_pred=rf.predict(x_test)
accuracy1 = accuracy_score(y_test, y_pred)
rf = rf = RandomForestClassifier(random_state = 0, criterion = 'gini')
rf.fit(x_train,y_train.ravel())
y_pred=rf.predict(x_test)
accuracy2 = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy1 * 100.0))
print("Accuracy: %.2f%%" % (accuracy2 * 100.0))
# Out:
# Accuracy: 77.92%
# Accuracy: 76.62%

# %%
scoreall = []
for i in range(1,500):
    rf = RandomForestClassifier(random_state = 0, criterion = 'entropy', n_estimators = i)
    rf.fit(x_train,y_train.ravel())
    y_pred=rf.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    scoreall.append([i ,accuracy])
scoreall = np.array(scoreall)
max_score = np.where(scoreall==np.max(scoreall[:,1]))[0][0]
print("最优参数以及最高得分:",scoreall[max_score])  
plt.figure(figsize=[20,5])
plt.plot(scoreall[:,0],scoreall[:,1])
plt.show()
# Out:
# 最优参数以及最高得分: [7.        0.7965368]

# %%
scoreall = []
for i in range(1,30):
    rf = RandomForestClassifier(random_state = 0, criterion = 'entropy', n_estimators = 7, max_depth = i)
    rf.fit(x_train,y_train)
    y_pred=rf.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    scoreall.append([i ,accuracy])
scoreall = np.array(scoreall)
max_score = np.where(scoreall==np.max(scoreall[:,1]))[0][0]
print("最优参数以及最高得分:",scoreall[max_score])  
plt.figure(figsize=[20,5])
plt.plot(scoreall[:,0],scoreall[:,1])
plt.show()
# Out:
# 最优参数以及最高得分: [18.         0.7965368]

# %%
scoreall = []
for i in range(1,100):
    rf = RandomForestClassifier(random_state = 0, criterion = 'entropy', n_estimators = 7, max_depth = 18, min_samples_split = i)
    rf.fit(x_train,y_train)
    y_pred=rf.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    scoreall.append([i ,accuracy])
scoreall = np.array(scoreall)
max_score = np.where(scoreall==np.max(scoreall[:,1]))[0][0]
print("最优参数以及最高得分:",scoreall[max_score])  
plt.figure(figsize=[20,5])
plt.plot(scoreall[:,0],scoreall[:,1])
plt.show()
# Out:
# 最优参数以及最高得分: [9.        0.8008658]

# %%
scoreall = []
for i in range(1,100):
    rf = RandomForestClassifier(random_state = 0, criterion = 'entropy', n_estimators = 7, max_depth = 18, min_samples_split = 9, min_samples_leaf = i)
    rf.fit(x_train,y_train)
    y_pred=rf.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    scoreall.append([i ,accuracy])
scoreall = np.array(scoreall)
max_score = np.where(scoreall==np.max(scoreall[:,1]))[0][0]
print("最优参数以及最高得分:",scoreall[max_score])  
plt.figure(figsize=[20,5])
plt.plot(scoreall[:,0],scoreall[:,1])
plt.show()
# Out:
# 最优参数以及最高得分: [1.        0.8008658]

# %%
rf = RandomForestClassifier(random_state = 0, criterion = 'entropy', n_estimators = 7, max_depth = 18, min_samples_split = 9, min_samples_leaf = 1)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 80.09%

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       158
#            1       0.67      0.74      0.70        73
#
#     accuracy                           0.80       231
#    macro avg       0.77      0.78      0.78       231
# weighted avg       0.81      0.80      0.80       231

# %%
confusion = confusion_matrix(y_pred, y_test)
df_cm = pd.DataFrame(confusion)
sns.heatmap(df_cm, annot=True)
# Out:
# <Axes: >
